# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random, collections
t = 0.0001
word_count = collections.Counter(int_words)
total_count = len(int_words)
freq = {word : count / total_count for word, count in word_count.items()}
prob = {word : 1 - np.sqrt(t / freq[word]) for word in word_count}
train_words = [word for word in int_words if prob[word] < random.random()] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    random_int = np.random.randint(1, window_size + 1)
    start = idx - random_int if (idx - random_int > 0) else 0
    end = idx + random_int
    target_words = set(words[start : idx] + words[idx + 1 : end])
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
# Out:
# WARNING:tensorflow:From C:\Users\Dell\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable((tf.truncated_normal([n_vocab, n_embedding]))) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab])) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\Dell\anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\Dell\anaconda3\lib\site-packages\tensorflow\python\ops\array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 18.5640 0.4672 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 18.3859 0.4950 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 18.1727 0.4714 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.9600 0.4516 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.8074 0.4178 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.5124 0.4954 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 17.4599 0.4116 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 17.3047 0.4215 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 17.0955 0.3937 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 17.0126 0.3830 sec/batch
# Nearest to not: cons, haigh, lilia, weicker, glossed, pianist, cloned, champs,
# Nearest to seven: danger, karenina, atlas, elegies, paralysis, asquith, creutzfeldt, arameans,
# Nearest to about: investigative, vpn, brancusi, stoll, dacko, kenya, fiendish, ranges,
# Nearest to often: gant, quinoa, guth, seminumerical, augusti, dimitris, framers, hawkins,
# Nearest to it: contiguous, rites, faris, logicians, appearances, prover, barada, arousing,
# Nearest to three: provider, torgau, atc, paradoxically, prevailed, theophrastus, fleetwood, reassured,
# Nearest to to: airframes, sabha, floresiensis, tutor, koce, masami, xxv, perpetrators,
# Nearest to also: ida, someday, ben, snowshoe, settling, malle, belsen, tribe,
# Nearest to orthodox: upriver, penni, disciples, heterotic, coset, legalizing, vetted, director,
# Nearest to dr: daryl, qualitatively, horde, sic, normans, separatist, illustrating, ascribe,
# Nearest to consists: alans, prevalent, hiroshi, zuma, categorizing, reactance, outlet, busta,
# Nearest to resources: slid, multipath, honduran, northern, enos, symbolism, frontage, haider,
# Nearest to taking: sloppy, restroom, valiente, edmunds, apiaceae, conradin, pauses, uni,
# Nearest to assembly: wilt, suzerain, poids, promiscuity, toynbee, urnfield, grammarian, champollion,
# Nearest to numerous: komi, ironside, henchmen, porphyry, faber, gpa, forcing, peachtree,
# Nearest to construction: gunboat, apocalypse, myrtle, safi, hearses, lech, carols, hafnium,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.8045 0.4131 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.7205 0.4589 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.5247 0.4436 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.3980 0.3995 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 16.2332 0.3937 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 16.0715 0.4191 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.8678 0.4394 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.8169 0.4123 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.6142 0.4176 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.5300 0.3951 sec/batch
# Nearest to not: cons, lilia, weicker, haigh, champs, glossed, whitcomb, ich,
# Nearest to seven: danger, karenina, melancholia, succ, itil, elegies, droit, asquith,
# Nearest to about: investigative, vpn, brancusi, stoll, bakelite, dyck, kenya, promise,
# Nearest to often: quinoa, augusti, gant, guth, fucked, seminumerical, framers, pasadena,
# Nearest to it: contiguous, appearances, rites, logicians, barada, arousing, football, steamships,
# Nearest to three: provider, atc, torgau, prevailed, paradoxically, fleetwood, reassured, cccc,
# Nearest to to: airframes, floresiensis, xxv, tutor, sabha, conjectured, koce, masami,
# Nearest to also: ida, ben, settling, someday, snowshoe, hechsher, tribe, hijaz,
# Nearest to orthodox: penni, upriver, coset, disciples, lewisham, director, brivla, heterotic,
# Nearest to dr: horde, qualitatively, daryl, sic, normans, separatist, illustrating, principle,
# Nearest to consists: alans, zuma, prevalent, busta, reactance, hiroshi, categorizing, donohue,
# Nearest to resources: slid, symbolism, honduran, multipath, enos, northern, frontage, markt,
# Nearest to taking: sloppy, valiente, restroom, edmunds, apiaceae, conradin, pauses, inscribed,
# Nearest to assembly: wilt, suzerain, poids, promiscuity, toynbee, urnfield, grammarian, champollion,
# Nearest to numerous: komi, ironside, henchmen, porphyry, faber, peachtree, gpa, gatherings,
# Nearest to construction: gunboat, apocalypse, myrtle, hearses, safi, lech, correspondent, hafnium,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.3651 0.4134 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.2704 0.4011 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 15.0286 0.4062 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 15.0023 0.4002 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 14.7750 0.4041 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.6696 0.4047 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.5915 0.4057 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.4301 0.4101 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.2478 0.4106 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 14.2341 0.4141 sec/batch
# Nearest to not: cons, lilia, whitcomb, weicker, glossed, lymphatic, haigh, champs,
# Nearest to seven: danger, karenina, succ, asquith, elegies, itil, melancholia, arameans,
# Nearest to about: investigative, vpn, dyck, stoll, bakelite, ovarian, brancusi, kenya,
# Nearest to often: quinoa, fucked, seminumerical, hawkins, guth, framers, gant, armas,
# Nearest to it: barada, appearances, rites, contiguous, football, certain, steamships, thirst,
# Nearest to three: provider, torgau, atc, paradoxically, prevailed, reassured, bootstrap, fleetwood,
# Nearest to to: airframes, conjectured, tutor, sabha, unary, diatribe, xxv, hussein,
# Nearest to also: ida, ben, settling, hechsher, snowshoe, someday, recently, tribe,
# Nearest to orthodox: heterotic, disciples, upriver, coset, lewisham, vetted, penni, finite,
# Nearest to dr: daryl, qualitatively, sic, illustrating, normans, horde, separatist, spongy,
# Nearest to consists: alans, zuma, prevalent, hiroshi, centres, donohue, busta, mughals,
# Nearest to resources: slid, honduran, up, symbolism, frontage, northern, enos, multipath,
# Nearest to taking: sloppy, valiente, restroom, apiaceae, conradin, pauses, anything, edmunds,
# Nearest to assembly: wilt, suzerain, toynbee, poids, promiscuity, grammarian, ircnet, urnfield,
# Nearest to numerous: komi, ironside, henchmen, porphyry, faber, silvers, peachtree, gatherings,
# Nearest to construction: gunboat, apocalypse, myrtle, hearses, safi, lech, correspondent, sparse,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 14.0761 0.4342 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 13.8991 0.4406 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 13.7780 0.4293 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 13.7813 0.4243 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 13.5510 0.4227 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 13.4893 0.4227 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.2486 0.4207 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 13.1566 0.4233 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 13.1443 0.4242 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 12.8948 0.4215 sec/batch
# Nearest to not: cons, in, lilia, glossed, weicker, lymphatic, haigh, terengganu,
# Nearest to seven: danger, five, which, the, is, asquith, an, karenina,
# Nearest to about: investigative, vpn, ovarian, undress, dyck, stoll, reducing, brancusi,
# Nearest to often: hawkins, fucked, armas, quinoa, seminumerical, symphonie, ferro, kouchner,
# Nearest to it: which, a, of, two, is, appearances, certain, barada,
# Nearest to three: provider, km, paradoxically, twisted, roofed, atc, reassured, ferber,
# Nearest to to: a, the, of, this, after, in, hussein, airframes,
# Nearest to also: the, recently, first, ida, ben, hechsher, dist, surfaced,
# Nearest to orthodox: t, disciples, paraguayan, penni, finite, lewisham, coset, epitaph,
# Nearest to dr: daryl, normans, sic, illustrating, qualitatively, horde, separatist, principle,
# Nearest to consists: alans, prevalent, zuma, donohue, outlet, hiroshi, busta, mughals,
# Nearest to resources: up, slid, honduran, frontage, northern, symbolism, enos, multipath,
# Nearest to taking: sloppy, apiaceae, uni, valiente, restroom, pauses, anything, numismatics,
# Nearest to assembly: suzerain, wilt, poids, toynbee, promiscuity, ircnet, grammarian, neutralist,
# Nearest to numerous: komi, ironside, henchmen, porphyry, silvers, faber, camcorders, khafre,
# Nearest to construction: gunboat, myrtle, apocalypse, hearses, safi, lech, correspondent, carols,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 12.9014 0.4324 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 12.7431 0.4537 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 12.6303 0.4444 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 12.5546 0.4150 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 12.5771 0.4226 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 12.2892 0.4139 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 12.1561 0.4869 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 11.9376 0.4550 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 11.9831 0.4476 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 11.8798 0.4489 sec/batch
# Nearest to not: in, of, the, and, to, on, by, is,
# Nearest to seven: the, five, which, of, in, and, is, this,
# Nearest to about: is, a, of, the, there, as, to, in,
# Nearest to often: a, s, for, masnavi, hawkins, armas, fucked, kouchner,
# Nearest to it: a, the, of, which, and, to, is, in,
# Nearest to three: the, of, a, on, and, to, is, in,
# Nearest to to: a, the, of, in, and, on, as, for,
# Nearest to also: the, a, as, and, to, in, of, on,
# Nearest to orthodox: t, finite, disciples, lewisham, grounded, epitaph, penni, indole,
# Nearest to dr: qualitatively, daryl, illustrating, sic, normans, horde, separatist, ascribe,
# Nearest to consists: alans, prevalent, outlet, mughals, centres, reconsidered, modulations, donohue,
# Nearest to resources: up, slid, honduran, northern, frontage, symbolism, boxy, enos,
# Nearest to taking: sloppy, apiaceae, anything, uni, restroom, numismatics, valiente, inscribed,
# Nearest to assembly: suzerain, wilt, toynbee, poids, ircnet, australia, promiscuity, grammarian,
# Nearest to numerous: komi, ironside, silvers, henchmen, camcorders, porphyry, secede, faber,
# Nearest to construction: myrtle, gunboat, apocalypse, safi, hearses, lech, correspondent, sparse,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 11.8123 0.4713 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 11.6957 0.4727 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 11.4746 0.4804 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 11.4787 0.4707 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 11.3158 0.4429 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 11.3204 0.4511 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 11.1342 0.4402 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 11.0653 0.4483 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 10.8570 0.4484 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 10.8999 0.4268 sec/batch
# Nearest to not: in, of, and, the, to, is, by, that,
# Nearest to seven: five, zero, by, two, of, the, one, an,
# Nearest to about: in, is, as, of, and, there, the, a,
# Nearest to often: a, s, and, as, in, of, this, to,
# Nearest to it: a, the, is, to, of, which, and, as,
# Nearest to three: one, on, two, of, zero, the, in, five,
# Nearest to to: the, in, of, a, and, as, is, for,
# Nearest to also: the, and, as, in, of, by, a, to,
# Nearest to orthodox: t, disciples, grounded, penni, epitaph, finite, vetted, arriving,
# Nearest to dr: illustrating, qualitatively, sic, daryl, principle, horde, separatist, normans,
# Nearest to consists: alans, prevalent, outlet, reconsidered, mughals, donohue, modulations, nine,
# Nearest to resources: up, northern, honduran, slid, frontage, schematics, logic, retrial,
# Nearest to taking: other, sloppy, anything, are, this, which, inscribed, uni,
# Nearest to assembly: wilt, toynbee, suzerain, poids, promiscuity, australia, characters, built,
# Nearest to numerous: komi, third, ironside, silvers, camcorders, mccoy, amass, faber,
# Nearest to construction: myrtle, gunboat, apocalypse, safi, hearses, churned, congressmen, sparse,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 10.6411 0.3972 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 10.6921 0.3852 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 10.5022 0.4102 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 10.8414 0.3879 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 10.4824 0.4090 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 10.3055 0.4024 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 10.2148 0.4069 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 10.1678 0.3966 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 10.3082 0.4047 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 10.1128 0.4136 sec/batch
# Nearest to not: that, to, is, but, it, a, this, which,
# Nearest to seven: one, five, eight, two, nine, four, three, zero,
# Nearest to about: a, for, is, also, this, in, and, the,
# Nearest to often: as, of, to, it, also, and, for, the,
# Nearest to it: is, to, a, the, that, for, as, this,
# Nearest to three: five, two, one, four, zero, eight, nine, six,
# Nearest to to: the, of, as, a, that, this, is, and,
# Nearest to also: of, the, and, for, a, to, in, other,
# Nearest to orthodox: t, grounded, director, disciples, profound, vetted, arriving, penni,
# Nearest to dr: qualitatively, illustrating, sic, principle, daryl, hitomaro, separatist, east,
# Nearest to consists: however, part, used, world, its, alans, outlet, always,
# Nearest to resources: northern, up, honduran, past, noting, slid, logic, frontage,
# Nearest to taking: are, is, however, has, who, this, and, other,
# Nearest to assembly: toynbee, built, characters, wilt, poids, australia, suzerain, promiscuity,
# Nearest to numerous: about, third, into, komi, world, was, many, when,
# Nearest to construction: myrtle, gunboat, apocalypse, safi, congressmen, medea, switches, deductions,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 9.7318 0.4079 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 9.8319 0.4062 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 10.0197 0.4075 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 9.8609 0.4046 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 9.6989 0.4253 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 9.6043 0.4818 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 9.2506 0.4448 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 9.4428 0.4482 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 9.3523 0.3815 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 9.3261 0.4015 sec/batch
# Nearest to not: to, that, a, is, but, this, the, have,
# Nearest to seven: eight, one, nine, six, four, five, three, two,
# Nearest to about: in, the, and, a, from, of, this, but,
# Nearest to often: a, not, as, are, they, the, these, to,
# Nearest to it: to, a, this, is, which, the, but, that,
# Nearest to three: four, two, one, five, six, zero, nine, eight,
# Nearest to to: the, a, of, that, in, and, this, which,
# Nearest to also: in, the, and, as, of, a, to, an,
# Nearest to orthodox: t, director, grounded, disciples, finite, profound, vetted, monitored,
# Nearest to dr: six, party, nine, sic, qualitatively, principle, illustrating, five,
# Nearest to consists: by, being, as, on, used, many, is, or,
# Nearest to resources: up, northern, a, modern, both, in, often, past,
# Nearest to taking: including, are, still, also, several, this, part, and,
# Nearest to assembly: built, world, australia, long, city, group, toynbee, neutralist,
# Nearest to numerous: about, just, into, world, when, time, other, often,
# Nearest to construction: myrtle, research, apocalypse, gunboat, within, thanks, press, congressmen,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 9.3006 0.3973 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 9.1771 0.3988 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 9.1354 0.4256 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 9.1248 0.0424 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 8.9046 0.4300 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 8.8629 0.4578 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 8.8565 0.4183 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 8.8154 0.3899 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 8.7591 0.4017 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 8.6995 0.4054 sec/batch
# Nearest to not: that, this, to, be, some, so, however, it,
# Nearest to seven: eight, one, nine, six, four, five, three, two,
# Nearest to about: the, it, on, in, from, of, a, an,
# Nearest to often: it, this, some, is, or, that, have, these,
# Nearest to it: that, to, is, an, which, this, the, a,
# Nearest to three: four, five, two, one, six, zero, eight, seven,
# Nearest to to: the, this, that, a, of, in, it, which,
# Nearest to also: the, which, a, in, most, an, is, to,
# Nearest to orthodox: t, director, highest, disciples, grounded, profound, monitored, stop,
# Nearest to dr: party, world, east, developed, zero, non, five, believed,
# Nearest to consists: may, part, use, however, world, far, which, due,
# Nearest to resources: example, up, modern, especially, for, still, see, may,
# Nearest to taking: part, including, often, is, many, it, by, considered,
# Nearest to assembly: built, came, until, into, long, so, second, city,
# Nearest to numerous: its, third, at, in, became, of, by, people,
# Nearest to construction: research, primarily, mid, now, myrtle, develop, throughout, rise,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 8.5735 0.4149 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 8.6715 0.3918 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 8.5805 0.3918 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 8.4989 0.4548 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 8.3941 0.4304 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 8.1926 0.3975 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 8.2569 0.3985 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 8.2646 0.3960 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 8.1683 0.3961 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 8.1419 0.3956 sec/batch
# Nearest to not: this, it, to, or, a, have, is, only,
# Nearest to seven: six, one, nine, eight, three, four, five, two,
# Nearest to about: in, and, on, has, the, of, from, a,
# Nearest to often: is, not, a, or, many, these, has, called,
# Nearest to it: to, this, is, a, or, be, but, may,
# Nearest to three: four, one, five, two, six, eight, seven, nine,
# Nearest to to: the, a, it, and, in, this, all, as,
# Nearest to also: and, in, a, the, of, is, to, as,
# Nearest to orthodox: t, director, highest, perhaps, on, basis, addition, nearly,
# Nearest to dr: developed, single, believed, party, united, nine, m, zero,
# Nearest to consists: part, the, are, most, always, may, of, in,
# Nearest to resources: given, instead, number, within, or, single, used, can,
# Nearest to taking: as, with, to, been, another, in, while, a,
# Nearest to assembly: until, second, while, after, who, built, and, group,
# Nearest to numerous: in, time, and, still, would, the, last, has,
# Nearest to construction: primarily, around, mid, research, makes, example, use, widely,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 8.1366 0.4320 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 8.0621 0.3972 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 7.7752 0.4116 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 7.7196 0.3992 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 7.7710 0.3945 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 7.8110 0.4123 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 7.7637 0.3979 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 7.7604 0.4050 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 7.8548 0.3992 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 7.8231 0.3936 sec/batch
# Nearest to not: that, a, it, they, is, to, which, this,
# Nearest to seven: four, six, one, three, eight, nine, five, two,
# Nearest to about: and, of, for, which, to, the, is, a,
# Nearest to often: it, or, are, which, that, some, generally, is,
# Nearest to it: to, is, a, that, which, and, this, however,
# Nearest to three: four, one, seven, five, eight, two, nine, zero,
# Nearest to to: a, it, and, the, with, which, in, of,
# Nearest to also: and, a, as, the, of, in, for, by,
# Nearest to orthodox: highest, director, always, many, high, note, basis, largely,
# Nearest to dr: national, march, little, soon, countries, late, at, run,
# Nearest to consists: is, change, within, may, which, on, the, part,
# Nearest to resources: available, part, possible, within, various, as, its, different,
# Nearest to taking: to, however, it, has, which, more, that, and,
# Nearest to assembly: him, until, allowed, supported, first, into, city, late,
# Nearest to numerous: the, in, over, were, at, as, those, during,
# Nearest to construction: large, while, others, primarily, other, modern, mid, together,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 7.7081 0.3977 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 7.6196 0.4020 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 7.3728 0.4272 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 7.6470 0.4363 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 7.4499 0.4221 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 7.5317 0.4450 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 7.5136 0.4195 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 7.5337 0.4110 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 7.4499 0.4135 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 7.2314 0.4103 sec/batch
# Nearest to not: that, but, is, which, it, to, be, would,
# Nearest to seven: six, eight, one, five, two, four, nine, three,
# Nearest to about: and, in, of, by, the, from, over, as,
# Nearest to often: to, this, are, such, is, many, or, that,
# Nearest to it: to, this, that, is, a, as, but, the,
# Nearest to three: two, four, one, six, five, seven, zero, eight,
# Nearest to to: that, as, the, a, it, this, which, many,
# Nearest to also: and, the, in, as, of, with, for, from,
# Nearest to orthodox: eastern, ancient, until, recently, following, entire, about, official,
# Nearest to dr: nine, national, television, s, two, one, february, began,
# Nearest to consists: other, is, a, into, called, may, between, an,
# Nearest to resources: available, use, related, similar, provide, these, may, a,
# Nearest to taking: to, that, the, as, there, but, itself, a,
# Nearest to assembly: him, saw, line, few, when, special, former, had,
# Nearest to numerous: and, in, many, the, from, by, now, also,
# Nearest to construction: the, large, used, including, in, sometimes, of, same,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 7.0443 0.4026 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 7.2383 0.4045 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 7.2604 0.4320 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 7.2155 0.4417 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 7.2120 0.4194 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 7.0533 0.4262 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 7.1559 0.4052 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 7.1246 0.4069 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 7.4081 0.4095 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 7.0611 0.4129 sec/batch
# Nearest to not: that, to, they, be, or, have, because, would,
# Nearest to seven: one, eight, six, five, nine, four, three, two,
# Nearest to about: of, on, a, which, and, in, all, by,
# Nearest to often: or, some, to, are, is, an, a, these,
# Nearest to it: a, that, as, is, to, this, have, or,
# Nearest to three: five, four, one, seven, six, two, eight, nine,
# Nearest to to: but, a, that, would, the, of, this, have,
# Nearest to also: and, a, for, the, of, in, with, its,
# Nearest to orthodox: eastern, ancient, roman, accepted, beginning, recently, christian, entire,
# Nearest to dr: three, zero, five, four, one, nine, late, television,
# Nearest to consists: into, a, an, for, are, called, is, its,
# Nearest to resources: use, other, for, more, common, required, is, large,
# Nearest to taking: a, this, to, all, being, it, has, only,
# Nearest to assembly: president, last, issue, following, late, brought, former, put,
# Nearest to numerous: and, in, several, the, of, by, since, have,
# Nearest to construction: large, and, a, found, many, its, including, small,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 6.8350 0.4190 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 6.7824 0.4094 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 6.9864 0.3989 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 6.9800 0.3922 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 7.0330 0.4254 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 6.8383 0.4147 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 6.7295 0.4171 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 6.8493 0.4638 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 6.7165 0.4395 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 6.8735 0.4114 sec/batch
# Nearest to not: or, it, because, that, be, but, so, may,
# Nearest to seven: one, six, eight, five, four, three, nine, two,
# Nearest to about: a, it, of, is, for, has, which, this,
# Nearest to often: are, or, even, many, such, but, is, this,
# Nearest to it: to, a, this, all, but, that, is, be,
# Nearest to three: five, one, six, seven, four, nine, eight, two,
# Nearest to to: a, with, for, of, the, that, this, but,
# Nearest to also: a, for, and, of, the, as, in, which,
# Nearest to orthodox: ancient, eastern, catholic, accepted, greek, while, widely, many,
# Nearest to dr: nine, series, eight, three, one, american, television, started,
# Nearest to consists: is, has, are, other, any, which, also, the,
# Nearest to resources: available, information, limited, development, commercial, provided, see, use,
# Nearest to taking: of, the, to, from, which, a, when, in,
# Nearest to assembly: next, members, first, met, held, s, former, prime,
# Nearest to numerous: and, of, most, including, several, many, although, in,
# Nearest to construction: also, which, along, for, built, to, various, other,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 6.7988 0.4159 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 6.8082 0.4448 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 6.5000 0.4312 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 6.6256 0.4077 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 6.5297 0.4114 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 6.5120 0.4468 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 6.5585 0.4370 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 6.7920 0.4474 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 6.5606 0.4377 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 6.5774 0.4095 sec/batch
# Nearest to not: that, have, they, it, so, fact, always, be,
# Nearest to seven: six, eight, four, one, five, three, nine, zero,
# Nearest to about: to, a, with, the, for, is, this, an,
# Nearest to often: these, itself, such, very, or, other, are, particular,
# Nearest to it: to, is, that, have, but, a, this, there,
# Nearest to three: four, five, six, two, zero, eight, seven, one,
# Nearest to to: a, the, which, but, it, that, with, as,
# Nearest to also: which, for, is, a, the, and, to, many,
# Nearest to orthodox: catholic, ancient, roman, recognized, christian, presence, church, accepted,
# Nearest to dr: general, zero, s, two, one, first, in, three,
# Nearest to consists: is, are, its, has, each, called, other, which,
# Nearest to resources: commercial, level, limited, natural, issues, providing, provided, development,
# Nearest to taking: to, well, when, as, never, though, for, which,
# Nearest to assembly: members, next, former, elected, office, administration, independent, fourth,
# Nearest to numerous: from, several, many, including, and, while, most, into,
# Nearest to construction: built, use, its, large, including, much, control, has,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 6.5074 0.4125 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 6.5545 0.4122 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 6.8447 0.4277 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 6.5053 0.4360 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 6.2022 0.5958 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 6.4689 0.4812 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 6.6544 0.4681 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 6.5326 0.4693 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 6.4476 0.4676 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 6.3222 0.4716 sec/batch
# Nearest to not: be, that, must, does, to, this, any, because,
# Nearest to seven: six, one, eight, four, five, three, nine, two,
# Nearest to about: and, to, a, of, the, with, an, in,
# Nearest to often: it, be, or, to, these, a, that, is,
# Nearest to it: to, that, a, is, this, as, be, but,
# Nearest to three: four, five, six, one, seven, two, zero, eight,
# Nearest to to: a, as, the, that, but, it, this, in,
# Nearest to also: and, in, the, has, of, a, as, to,
# Nearest to orthodox: roman, catholic, accepted, religious, church, christian, currently, religion,
# Nearest to dr: john, born, peter, robert, american, one, april, three,
# Nearest to consists: is, the, a, or, an, as, are, called,
# Nearest to resources: provide, development, information, wide, limited, and, level, commercial,
# Nearest to taking: a, to, that, in, with, as, their, the,
# Nearest to assembly: members, elected, president, member, held, national, political, government,
# Nearest to numerous: and, the, in, from, has, of, been, well,
# Nearest to construction: large, and, in, has, the, from, through, due,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 6.1180 0.4759 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 6.4057 0.4987 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 6.2702 0.5146 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 6.2995 0.4734 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 6.3142 0.4918 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 6.3218 0.5057 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 6.3312 0.4950 sec/batch
# Epoch 3/10 Iteration: 16800 Avg. Training loss: 6.3283 0.1134 sec/batch
# Epoch 3/10 Iteration: 16900 Avg. Training loss: 6.2399 0.4713 sec/batch
# Epoch 3/10 Iteration: 17000 Avg. Training loss: 6.1388 0.4701 sec/batch
# Nearest to not: that, this, so, do, without, any, be, same,
# Nearest to seven: one, eight, six, nine, four, three, five, two,
# Nearest to about: of, a, the, on, which, and, from, in,
# Nearest to often: some, these, or, many, that, are, more, it,
# Nearest to it: to, that, this, a, as, but, be, is,
# Nearest to three: two, five, six, one, four, zero, seven, eight,
# Nearest to to: the, a, in, which, and, but, that, as,
# Nearest to also: and, a, as, of, in, the, including, to,
# Nearest to orthodox: catholic, church, religious, religion, christian, roman, tradition, ancient,
# Nearest to dr: david, nine, john, one, richard, james, peter, career,
# Nearest to consists: is, of, which, a, are, the, except, an,
# Nearest to resources: development, limited, natural, extensive, significant, its, information, providing,
# Nearest to taking: that, take, only, to, this, a, when, all,
# Nearest to assembly: members, elected, held, branch, council, party, government, vote,
# Nearest to numerous: of, the, its, most, including, and, into, to,
# Nearest to construction: including, and, its, due, high, industry, building, over,
# Epoch 3/10 Iteration: 17100 Avg. Training loss: 6.2091 0.4751 sec/batch
# Epoch 3/10 Iteration: 17200 Avg. Training loss: 6.2698 0.6591 sec/batch
# Epoch 3/10 Iteration: 17300 Avg. Training loss: 6.2316 0.4912 sec/batch
# Epoch 3/10 Iteration: 17400 Avg. Training loss: 6.1590 0.4640 sec/batch
# Epoch 3/10 Iteration: 17500 Avg. Training loss: 6.0567 0.4820 sec/batch
# Epoch 3/10 Iteration: 17600 Avg. Training loss: 6.1751 0.4595 sec/batch
# Epoch 3/10 Iteration: 17700 Avg. Training loss: 6.2592 0.4638 sec/batch
# Epoch 3/10 Iteration: 17800 Avg. Training loss: 6.0884 0.4709 sec/batch
# Epoch 3/10 Iteration: 17900 Avg. Training loss: 5.9829 0.4589 sec/batch
# Epoch 3/10 Iteration: 18000 Avg. Training loss: 5.8842 0.4564 sec/batch
# Nearest to not: that, this, be, because, without, however, would, some,
# Nearest to seven: one, eight, six, five, nine, four, three, two,
# Nearest to about: from, in, of, a, it, and, the, an,
# Nearest to often: these, some, sometimes, or, such, used, common, many,
# Nearest to it: a, to, which, this, all, is, more, but,
# Nearest to three: five, four, two, six, one, seven, eight, zero,
# Nearest to to: which, as, the, it, a, of, and, however,
# Nearest to also: and, the, in, of, on, as, for, a,
# Nearest to orthodox: church, catholic, roman, christian, tradition, religious, christians, religion,
# Nearest to dr: david, john, nine, james, robert, richard, s, peter,
# Nearest to consists: is, the, of, each, are, which, its, and,
# Nearest to resources: development, natural, includes, extensive, provides, providing, limited, environment,
# Nearest to taking: to, only, this, that, a, having, another, even,
# Nearest to assembly: members, elected, branch, executive, held, council, elections, representatives,
# Nearest to numerous: and, many, of, the, including, in, which, as,
# Nearest to construction: large, small, and, its, building, a, in, including,
# Epoch 3/10 Iteration: 18100 Avg. Training loss: 6.0496 0.4594 sec/batch
# Epoch 3/10 Iteration: 18200 Avg. Training loss: 6.0366 0.5241 sec/batch
# Epoch 3/10 Iteration: 18300 Avg. Training loss: 6.0025 0.4756 sec/batch
# Epoch 3/10 Iteration: 18400 Avg. Training loss: 6.0238 0.4775 sec/batch
# Epoch 3/10 Iteration: 18500 Avg. Training loss: 6.0439 0.4932 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 5.9924 0.4653 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 5.7152 0.5329 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 5.7599 0.4953 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 5.8201 0.4991 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 5.7907 0.4830 sec/batch
# Nearest to not: that, it, be, this, but, even, to, does,
# Nearest to seven: eight, four, five, one, six, three, nine, zero,
# Nearest to about: and, with, from, a, of, in, on, the,
# Nearest to often: some, such, sometimes, these, it, this, certain, or,
# Nearest to it: this, that, to, or, is, which, have, even,
# Nearest to three: four, five, six, one, two, eight, zero, nine,
# Nearest to to: this, as, a, which, it, their, for, however,
# Nearest to also: the, with, other, in, of, which, as, and,
# Nearest to orthodox: catholic, church, roman, christian, christians, religious, christianity, protestant,
# Nearest to dr: james, john, richard, david, peter, michael, american, career,
# Nearest to consists: which, of, both, are, is, in, an, the,
# Nearest to resources: natural, extensive, limited, environment, development, developing, issues, important,
# Nearest to taking: to, a, their, on, this, having, time, take,
# Nearest to assembly: branch, members, executive, elected, held, elections, legislative, appointed,
# Nearest to numerous: and, the, of, in, from, several, part, were,
# Nearest to construction: its, large, building, including, important, industrial, completed, built,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 5.8291 0.4319 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 5.8734 0.4049 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 5.9815 0.4177 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 5.9615 0.4159 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 5.9060 0.4084 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 5.7955 0.4276 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 5.6644 0.4269 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 5.9503 0.3931 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 5.7255 0.3962 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 5.8065 0.3897 sec/batch
# Nearest to not: that, do, be, this, have, however, fact, should,
# Nearest to seven: eight, three, six, five, one, four, nine, two,
# Nearest to about: and, the, of, from, has, all, in, is,
# Nearest to often: or, are, other, such, it, this, is, generally,
# Nearest to it: is, this, that, or, to, so, but, as,
# Nearest to three: four, five, seven, six, one, eight, two, nine,
# Nearest to to: the, would, as, but, for, this, and, being,
# Nearest to also: and, as, the, with, has, of, from, most,
# Nearest to orthodox: catholic, church, roman, christian, christians, christianity, protestant, religion,
# Nearest to dr: david, michael, film, s, peter, frank, richard, nine,
# Nearest to consists: other, relatively, is, are, there, consisting, unlike, has,
# Nearest to resources: developing, limited, issues, environment, extensive, its, providing, resource,
# Nearest to taking: to, the, a, while, with, when, an, and,
# Nearest to assembly: elected, elections, branch, legislative, representatives, vote, members, held,
# Nearest to numerous: today, the, and, of, in, as, also, far,
# Nearest to construction: built, large, the, mostly, its, and, build, of,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 5.8417 0.3867 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 5.8954 0.4011 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 5.8397 0.3941 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 5.6144 0.3865 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 5.5961 0.4122 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 5.6311 0.3996 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 5.7345 0.3952 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 5.6839 0.3957 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 5.7291 0.3876 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 5.6125 0.4044 sec/batch
# Nearest to not: that, should, this, they, be, any, rather, it,
# Nearest to seven: six, eight, five, nine, four, three, one, two,
# Nearest to about: and, the, on, for, a, little, in, also,
# Nearest to often: or, as, is, rather, such, which, some, this,
# Nearest to it: that, to, a, this, they, have, so, but,
# Nearest to three: five, two, four, six, seven, one, zero, eight,
# Nearest to to: that, it, but, the, they, their, however, a,
# Nearest to also: and, with, for, as, from, a, well, the,
# Nearest to orthodox: catholic, church, roman, christian, christians, churches, christianity, eastern,
# Nearest to dr: peter, director, james, s, film, robert, michael, david,
# Nearest to consists: has, the, is, of, formed, divided, are, there,
# Nearest to resources: limited, issues, developing, development, use, provide, environment, industrial,
# Nearest to taking: to, it, a, that, this, an, when, may,
# Nearest to assembly: elected, elections, legislative, parliament, representatives, branch, president, members,
# Nearest to numerous: and, the, has, of, several, in, now, from,
# Nearest to construction: built, building, large, major, transport, limited, its, opened,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 5.6558 0.4156 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 5.6496 0.4266 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 5.8415 0.3930 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 5.6653 0.3974 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 5.4971 0.4718 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 5.4038 0.4278 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 5.6145 0.4607 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 5.6789 0.4288 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 5.7186 0.4217 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 5.5721 0.4264 sec/batch
# Nearest to not: that, should, do, they, does, or, be, have,
# Nearest to seven: eight, one, six, five, four, nine, three, zero,
# Nearest to about: a, and, on, for, an, to, the, of,
# Nearest to often: or, are, other, such, these, many, sometimes, have,
# Nearest to it: to, that, this, so, some, a, they, have,
# Nearest to three: four, five, zero, six, one, two, seven, eight,
# Nearest to to: the, a, and, this, that, it, but, as,
# Nearest to also: a, for, and, to, an, as, has, most,
# Nearest to orthodox: church, catholic, christian, christians, churches, christianity, protestant, religious,
# Nearest to dr: peter, robert, james, director, david, jr, john, film,
# Nearest to consists: consisting, are, has, usually, is, each, other, terms,
# Nearest to resources: development, resource, information, limited, services, available, technology, provide,
# Nearest to taking: to, would, take, of, that, but, as, and,
# Nearest to assembly: parliament, elections, elected, legislative, members, vote, representatives, party,
# Nearest to numerous: the, in, period, throughout, and, various, has, many,
# Nearest to construction: built, building, constructed, large, buildings, high, transport, industrial,
# Epoch 3/10 Iteration: 22100 Avg. Training loss: 5.5055 0.4511 sec/batch
# Epoch 3/10 Iteration: 22200 Avg. Training loss: 5.5762 0.4598 sec/batch
# Epoch 3/10 Iteration: 22300 Avg. Training loss: 5.5111 0.4299 sec/batch
# Epoch 3/10 Iteration: 22400 Avg. Training loss: 5.5944 0.4182 sec/batch
# Epoch 3/10 Iteration: 22500 Avg. Training loss: 5.5556 0.4328 sec/batch
# Epoch 3/10 Iteration: 22600 Avg. Training loss: 5.6092 0.4185 sec/batch
# Epoch 3/10 Iteration: 22700 Avg. Training loss: 5.2842 0.4326 sec/batch
# Epoch 3/10 Iteration: 22800 Avg. Training loss: 5.4287 0.4191 sec/batch
# Epoch 3/10 Iteration: 22900 Avg. Training loss: 5.4294 0.4072 sec/batch
# Epoch 3/10 Iteration: 23000 Avg. Training loss: 5.3919 0.4226 sec/batch
# Nearest to not: that, have, it, be, even, should, does, so,
# Nearest to seven: four, five, one, three, six, nine, eight, two,
# Nearest to about: in, and, of, from, the, has, with, for,
# Nearest to often: these, such, other, as, or, have, this, many,
# Nearest to it: to, have, that, a, or, is, this, even,
# Nearest to three: four, five, six, one, zero, eight, two, seven,
# Nearest to to: have, it, the, a, however, their, which, this,
# Nearest to also: as, of, an, and, for, the, which, a,
# Nearest to orthodox: church, catholic, christian, christians, churches, christianity, protestant, doctrine,
# Nearest to dr: director, peter, robert, michael, paul, scientist, david, john,
# Nearest to consists: and, the, of, has, in, consisting, for, by,
# Nearest to resources: resource, development, include, including, services, agricultural, extensive, provided,
# Nearest to taking: would, when, take, but, to, having, could, made,
# Nearest to assembly: elections, legislative, members, parliament, elected, approved, constitution, held,
# Nearest to numerous: and, in, several, most, from, particularly, of, the,
# Nearest to construction: building, built, transportation, transport, large, major, constructed, over,
# Epoch 3/10 Iteration: 23100 Avg. Training loss: 5.4361 0.4176 sec/batch
# Epoch 3/10 Iteration: 23200 Avg. Training loss: 5.5095 0.4340 sec/batch
# Epoch 3/10 Iteration: 23300 Avg. Training loss: 5.4155 0.4180 sec/batch
# Epoch 3/10 Iteration: 23400 Avg. Training loss: 5.4558 0.4586 sec/batch
# Epoch 3/10 Iteration: 23500 Avg. Training loss: 5.4481 0.3910 sec/batch
# Epoch 3/10 Iteration: 23600 Avg. Training loss: 5.5847 0.4542 sec/batch
# Epoch 3/10 Iteration: 23700 Avg. Training loss: 5.7516 0.4410 sec/batch
# Epoch 3/10 Iteration: 23800 Avg. Training loss: 5.4405 0.4241 sec/batch
# Epoch 3/10 Iteration: 23900 Avg. Training loss: 5.2077 0.4156 sec/batch
# Epoch 3/10 Iteration: 24000 Avg. Training loss: 5.4810 0.4191 sec/batch
# Nearest to not: that, be, should, any, have, do, rather, this,
# Nearest to seven: six, four, five, eight, three, one, nine, two,
# Nearest to about: with, a, for, from, an, it, and, to,
# Nearest to often: some, such, or, these, be, more, sometimes, various,
# Nearest to it: to, this, but, a, that, have, could, there,
# Nearest to three: four, five, six, seven, two, one, zero, eight,
# Nearest to to: the, as, which, it, but, would, a, their,
# Nearest to also: and, of, in, most, the, has, by, which,
# Nearest to orthodox: church, jewish, christian, catholic, christians, christianity, religious, churches,
# Nearest to dr: director, james, jr, john, david, robert, peter, paul,
# Nearest to consists: consisting, is, and, has, the, its, of, mostly,
# Nearest to resources: natural, limited, environment, environmental, agricultural, provide, development, resource,
# Nearest to taking: to, a, would, an, out, take, with, their,
# Nearest to assembly: elected, elections, vote, members, legislative, approved, parliament, representatives,
# Nearest to numerous: and, of, been, several, in, the, today, including,
# Nearest to construction: large, high, relatively, commercial, built, industrial, limited, level,
# Epoch 3/10 Iteration: 24100 Avg. Training loss: 5.5613 0.4237 sec/batch
# Epoch 3/10 Iteration: 24200 Avg. Training loss: 5.4910 0.4261 sec/batch
# Epoch 3/10 Iteration: 24300 Avg. Training loss: 5.4016 0.4089 sec/batch
# Epoch 3/10 Iteration: 24400 Avg. Training loss: 5.2776 0.4115 sec/batch
# Epoch 3/10 Iteration: 24500 Avg. Training loss: 5.1921 0.4159 sec/batch
# Epoch 3/10 Iteration: 24600 Avg. Training loss: 5.3991 0.4213 sec/batch
# Epoch 3/10 Iteration: 24700 Avg. Training loss: 5.2746 0.3992 sec/batch
# Epoch 3/10 Iteration: 24800 Avg. Training loss: 5.3663 0.4103 sec/batch
# Epoch 3/10 Iteration: 24900 Avg. Training loss: 5.3857 0.4045 sec/batch
# Epoch 3/10 Iteration: 25000 Avg. Training loss: 5.3631 0.4072 sec/batch
# Nearest to not: that, be, but, do, should, so, even, might,
# Nearest to seven: one, eight, four, nine, five, six, three, two,
# Nearest to about: the, an, from, of, a, also, s, on,
# Nearest to often: or, as, sometimes, other, generally, example, more, it,
# Nearest to it: to, this, but, that, be, a, which, as,
# Nearest to three: two, five, four, six, zero, one, seven, eight,
# Nearest to to: but, the, it, time, only, which, would, their,
# Nearest to also: as, most, a, which, and, the, other, of,
# Nearest to orthodox: christianity, church, christians, christian, jewish, catholic, churches, religious,
# Nearest to dr: david, james, jr, jack, richard, director, peter, john,
# Nearest to consists: is, provides, are, small, non, note, separate, additional,
# Nearest to resources: resource, development, services, limited, agricultural, environment, natural, includes,
# Nearest to taking: to, but, would, when, the, take, time, their,
# Nearest to assembly: legislative, elections, branch, elected, vote, executive, parliament, members,
# Nearest to numerous: well, and, several, has, most, from, recently, including,
# Nearest to construction: agricultural, large, industrial, transportation, industry, infrastructure, transport, facilities,
# Epoch 3/10 Iteration: 25100 Avg. Training loss: 5.4408 0.4015 sec/batch
# Epoch 4/10 Iteration: 25200 Avg. Training loss: 5.3999 0.1351 sec/batch
# Epoch 4/10 Iteration: 25300 Avg. Training loss: 5.2615 0.4081 sec/batch
# Epoch 4/10 Iteration: 25400 Avg. Training loss: 5.3063 0.4164 sec/batch
# Epoch 4/10 Iteration: 25500 Avg. Training loss: 5.3059 0.4296 sec/batch
# Epoch 4/10 Iteration: 25600 Avg. Training loss: 5.4015 0.4141 sec/batch
# Epoch 4/10 Iteration: 25700 Avg. Training loss: 5.3591 0.4142 sec/batch
# Epoch 4/10 Iteration: 25800 Avg. Training loss: 5.2664 0.3969 sec/batch
# Epoch 4/10 Iteration: 25900 Avg. Training loss: 5.2532 0.4244 sec/batch
# ...
# Epoch 10/10 Iteration: 75900 Avg. Training loss: 4.2770 0.3977 sec/batch
# Epoch 10/10 Iteration: 76000 Avg. Training loss: 4.2815 0.4747 sec/batch
# Nearest to not: that, does, therefore, be, any, but, because, do,
# Nearest to seven: one, eight, four, five, six, three, two, nine,
# Nearest to about: on, from, approximately, this, zero, references, times, estimate,
# Nearest to often: sometimes, especially, many, particularly, some, such, frequently, generally,
# Nearest to it: but, this, which, is, that, because, so, be,
# Nearest to three: two, five, four, six, one, seven, eight, zero,
# Nearest to to: the, but, that, and, when, in, they, while,
# Nearest to also: is, see, other, in, of, and, as, called,
# Nearest to orthodox: orthodoxy, churches, catholic, christian, christians, church, eastern, christianity,
# Nearest to dr: professor, researcher, david, doctor, jr, alan, dean, hopkins,
# Nearest to consists: consist, consisting, each, comprises, composed, branch, assembly, are,
# Nearest to resources: resource, natural, arable, extensive, environment, issues, comprehensive, reserves,
# Nearest to taking: take, out, up, course, giving, when, returned, then,
# Nearest to assembly: legislative, branch, consists, multi, representation, seats, deputies, members,
# Nearest to numerous: including, many, various, well, several, mostly, most, some,
# Nearest to construction: building, constructed, built, opened, completed, buildings, tunnels, concrete,
# Epoch 10/10 Iteration: 76100 Avg. Training loss: 4.2715 0.4883 sec/batch
# Epoch 10/10 Iteration: 76200 Avg. Training loss: 4.2668 0.4718 sec/batch
# Epoch 10/10 Iteration: 76300 Avg. Training loss: 4.2567 0.5395 sec/batch
# Epoch 10/10 Iteration: 76400 Avg. Training loss: 4.3007 0.5295 sec/batch
# Epoch 10/10 Iteration: 76500 Avg. Training loss: 4.2635 0.5089 sec/batch
# Epoch 10/10 Iteration: 76600 Avg. Training loss: 4.2481 0.4926 sec/batch
# Epoch 10/10 Iteration: 76700 Avg. Training loss: 4.2059 0.4981 sec/batch
# Epoch 10/10 Iteration: 76800 Avg. Training loss: 4.2033 0.5066 sec/batch
# Epoch 10/10 Iteration: 76900 Avg. Training loss: 4.2961 0.4950 sec/batch
# Epoch 10/10 Iteration: 77000 Avg. Training loss: 4.2600 0.4954 sec/batch
# Nearest to not: be, does, that, do, any, it, no, to,
# Nearest to seven: one, five, four, three, eight, six, two, zero,
# Nearest to about: zero, according, references, life, approximately, two, estimate, five,
# Nearest to often: sometimes, occasionally, frequently, some, usually, such, generally, typically,
# Nearest to it: be, that, to, but, this, so, not, the,
# Nearest to three: two, four, five, one, six, seven, eight, zero,
# Nearest to to: a, the, it, they, only, that, but, this,
# Nearest to also: and, most, in, other, known, as, of, the,
# Nearest to orthodox: catholic, orthodoxy, church, christian, churches, christians, christianity, roman,
# Nearest to dr: professor, doctor, jr, dean, robert, david, kenneth, johns,
# Nearest to consists: consisting, consist, are, divided, comprises, is, composed, branch,
# Nearest to resources: resource, natural, arable, environment, deposits, agricultural, extensive, issues,
# Nearest to taking: take, to, when, up, a, took, at, on,
# Nearest to assembly: legislative, elected, council, elections, parliament, branch, deputies, members,
# Nearest to numerous: including, many, several, notably, mostly, most, included, well,
# Nearest to construction: building, constructed, built, buildings, completed, opened, manufacturing, build,
# Epoch 10/10 Iteration: 77100 Avg. Training loss: 4.3017 0.4931 sec/batch
# Epoch 10/10 Iteration: 77200 Avg. Training loss: 4.2876 0.4951 sec/batch
# Epoch 10/10 Iteration: 77300 Avg. Training loss: 4.3001 0.4927 sec/batch
# Epoch 10/10 Iteration: 77400 Avg. Training loss: 4.2377 0.4884 sec/batch
# Epoch 10/10 Iteration: 77500 Avg. Training loss: 4.1775 0.4962 sec/batch
# Epoch 10/10 Iteration: 77600 Avg. Training loss: 4.0932 0.4958 sec/batch
# Epoch 10/10 Iteration: 77700 Avg. Training loss: 4.2523 0.4940 sec/batch
# Epoch 10/10 Iteration: 77800 Avg. Training loss: 4.1713 0.4952 sec/batch
# Epoch 10/10 Iteration: 77900 Avg. Training loss: 4.2138 0.4987 sec/batch
# Epoch 10/10 Iteration: 78000 Avg. Training loss: 4.2058 0.5421 sec/batch
# Nearest to not: does, be, that, any, but, to, fact, therefore,
# Nearest to seven: one, six, eight, five, three, four, two, zero,
# Nearest to about: zero, from, according, on, three, there, two, and,
# Nearest to often: such, sometimes, generally, some, as, most, well, use,
# Nearest to it: but, that, to, this, so, which, be, because,
# Nearest to three: four, two, five, six, one, zero, seven, eight,
# Nearest to to: that, this, it, but, be, they, another, so,
# Nearest to also: in, and, known, most, other, include, as, see,
# Nearest to orthodox: orthodoxy, catholic, churches, church, christians, christianity, christian, catholicism,
# Nearest to dr: professor, research, institute, kenneth, dean, department, jr, michael,
# Nearest to consists: consisting, consist, separate, divided, each, are, is, called,
# Nearest to resources: resource, natural, issues, provides, extensive, environmental, information, provide,
# Nearest to taking: take, to, obtain, out, condition, after, when, giving,
# Nearest to assembly: legislative, elected, deputies, branch, council, cabinet, appointed, chosen,
# Nearest to numerous: including, various, extensive, many, mostly, well, notably, these,
# Nearest to construction: building, constructed, built, completed, tunnels, buildings, architectural, manufacturing,
# Epoch 10/10 Iteration: 78100 Avg. Training loss: 4.2482 0.5228 sec/batch
# Epoch 10/10 Iteration: 78200 Avg. Training loss: 4.2703 0.4947 sec/batch
# Epoch 10/10 Iteration: 78300 Avg. Training loss: 4.2485 0.4858 sec/batch
# Epoch 10/10 Iteration: 78400 Avg. Training loss: 4.2430 0.4695 sec/batch
# Epoch 10/10 Iteration: 78500 Avg. Training loss: 4.2754 0.4753 sec/batch
# Epoch 10/10 Iteration: 78600 Avg. Training loss: 4.2111 0.4679 sec/batch
# Epoch 10/10 Iteration: 78700 Avg. Training loss: 4.2390 0.4766 sec/batch
# Epoch 10/10 Iteration: 78800 Avg. Training loss: 4.2427 0.4715 sec/batch
# Epoch 10/10 Iteration: 78900 Avg. Training loss: 4.2951 0.4719 sec/batch
# Epoch 10/10 Iteration: 79000 Avg. Training loss: 4.3096 0.4696 sec/batch
# Nearest to not: that, does, be, because, should, but, so, only,
# Nearest to seven: one, eight, three, five, six, four, nine, two,
# Nearest to about: according, life, reported, account, that, have, how, zero,
# Nearest to often: sometimes, generally, or, some, as, are, especially, such,
# Nearest to it: that, to, but, so, this, not, because, be,
# Nearest to three: four, two, five, six, seven, one, zero, eight,
# Nearest to to: be, it, so, but, when, will, a, instead,
# Nearest to also: and, in, see, of, as, with, known, the,
# Nearest to orthodox: orthodoxy, catholic, churches, church, christianity, oriental, eastern, christians,
# Nearest to dr: professor, s, episode, doctor, dean, research, revealed, documentary,
# Nearest to consists: consisting, consist, divided, each, composed, separate, comprises, serve,
# Nearest to resources: resource, information, management, database, natural, comprehensive, projects, online,
# Nearest to taking: a, then, at, where, take, following, an, if,
# Nearest to assembly: legislative, elected, deputies, council, appointed, cabinet, elections, branch,
# Nearest to numerous: many, several, including, most, various, well, notably, among,
# Nearest to construction: constructed, built, building, completed, buildings, tunnels, concrete, opened,
# Epoch 10/10 Iteration: 79100 Avg. Training loss: 4.2429 0.4728 sec/batch
# Epoch 10/10 Iteration: 79200 Avg. Training loss: 4.1751 0.4755 sec/batch
# Epoch 10/10 Iteration: 79300 Avg. Training loss: 4.2052 0.4653 sec/batch
# Epoch 10/10 Iteration: 79400 Avg. Training loss: 4.2790 0.4692 sec/batch
# Epoch 10/10 Iteration: 79500 Avg. Training loss: 4.2219 0.4835 sec/batch
# Epoch 10/10 Iteration: 79600 Avg. Training loss: 4.3125 0.5022 sec/batch
# Epoch 10/10 Iteration: 79700 Avg. Training loss: 4.1879 0.4900 sec/batch
# Epoch 10/10 Iteration: 79800 Avg. Training loss: 4.1998 0.4525 sec/batch
# Epoch 10/10 Iteration: 79900 Avg. Training loss: 4.2752 0.3945 sec/batch
# Epoch 10/10 Iteration: 80000 Avg. Training loss: 4.2366 0.3743 sec/batch
# Nearest to not: any, that, does, be, should, cannot, if, but,
# Nearest to seven: six, five, one, three, eight, four, two, nine,
# Nearest to about: how, what, find, articles, this, why, it, references,
# Nearest to often: such, sometimes, usually, or, as, frequently, generally, used,
# Nearest to it: but, that, this, not, so, to, does, only,
# Nearest to three: four, two, five, six, seven, one, eight, zero,
# Nearest to to: would, so, it, the, only, that, this, but,
# Nearest to also: see, and, as, other, with, the, related, is,
# Nearest to orthodox: orthodoxy, church, churches, catholic, eastern, oriental, christians, christian,
# Nearest to dr: dean, doctor, revealed, director, mr, gordon, producer, professor,
# Nearest to consists: consisting, consist, divided, are, each, composed, comprises, comprising,
# Nearest to resources: resource, comprehensive, natural, issues, concerns, information, environment, provide,
# Nearest to taking: a, to, at, take, then, where, the, this,
# Nearest to assembly: legislative, elected, deputies, legislature, appointed, serve, branch, parliament,
# Nearest to numerous: several, including, many, mostly, notably, dozens, included, were,
# Nearest to construction: constructed, building, built, opened, buildings, concrete, completed, rebuilt,
# Epoch 10/10 Iteration: 80100 Avg. Training loss: 4.2676 0.3865 sec/batch
# Epoch 10/10 Iteration: 80200 Avg. Training loss: 4.1821 0.3801 sec/batch
# Epoch 10/10 Iteration: 80300 Avg. Training loss: 4.1221 0.3918 sec/batch
# Epoch 10/10 Iteration: 80400 Avg. Training loss: 4.2828 0.3948 sec/batch
# Epoch 10/10 Iteration: 80500 Avg. Training loss: 4.2641 0.3926 sec/batch
# Epoch 10/10 Iteration: 80600 Avg. Training loss: 4.2861 0.4072 sec/batch
# Epoch 10/10 Iteration: 80700 Avg. Training loss: 4.2802 0.3954 sec/batch
# Epoch 10/10 Iteration: 80800 Avg. Training loss: 4.2092 0.3969 sec/batch
# Epoch 10/10 Iteration: 80900 Avg. Training loss: 4.2690 0.3940 sec/batch
# Epoch 10/10 Iteration: 81000 Avg. Training loss: 4.2173 0.3926 sec/batch
# Nearest to not: be, that, any, does, do, even, would, always,
# Nearest to seven: one, eight, five, four, six, three, two, nine,
# Nearest to about: according, zero, how, times, estimate, have, estimates, there,
# Nearest to often: sometimes, such, some, usually, common, generally, or, are,
# Nearest to it: that, this, not, still, but, however, be, only,
# Nearest to three: five, four, seven, one, six, eight, two, zero,
# Nearest to to: the, allowed, and, a, when, would, instead, however,
# Nearest to also: see, and, as, list, an, such, of, other,
# Nearest to orthodox: orthodoxy, church, churches, catholic, eastern, oriental, christians, patriarch,
# Nearest to dr: professor, vol, david, dean, director, michael, doctor, institute,
# Nearest to consists: consisting, consist, divided, branch, each, are, comprising, divisions,
# Nearest to resources: resource, natural, information, environment, tools, arable, comprehensive, project,
# Nearest to taking: another, a, then, when, take, where, to, off,
# Nearest to assembly: legislative, elected, deputies, branch, members, appointed, elections, council,
# Nearest to numerous: many, several, most, including, well, various, and, been,
# Nearest to construction: constructed, building, built, buildings, bridges, opened, tunnels, build,
# Epoch 10/10 Iteration: 81100 Avg. Training loss: 4.2660 0.3997 sec/batch
# Epoch 10/10 Iteration: 81200 Avg. Training loss: 4.2665 0.4028 sec/batch
# Epoch 10/10 Iteration: 81300 Avg. Training loss: 4.2500 0.4004 sec/batch
# Epoch 10/10 Iteration: 81400 Avg. Training loss: 4.1420 0.3959 sec/batch
# Epoch 10/10 Iteration: 81500 Avg. Training loss: 4.1900 0.4002 sec/batch
# Epoch 10/10 Iteration: 81600 Avg. Training loss: 4.2251 0.4000 sec/batch
# Epoch 10/10 Iteration: 81700 Avg. Training loss: 4.1852 0.3971 sec/batch
# Epoch 10/10 Iteration: 81800 Avg. Training loss: 4.2721 0.3946 sec/batch
# Epoch 10/10 Iteration: 81900 Avg. Training loss: 4.1010 0.3953 sec/batch
# Epoch 10/10 Iteration: 82000 Avg. Training loss: 4.1623 0.4017 sec/batch
# Nearest to not: be, that, did, do, it, but, does, should,
# Nearest to seven: six, four, eight, one, five, three, two, zero,
# Nearest to about: zero, on, from, references, this, news, how, have,
# Nearest to often: sometimes, usually, some, such, common, occasionally, frequently, especially,
# Nearest to it: not, but, only, be, that, because, so, is,
# Nearest to three: four, five, six, seven, two, eight, one, zero,
# Nearest to to: would, while, but, when, that, a, the, so,
# Nearest to also: as, see, is, other, and, of, for, such,
# Nearest to orthodox: orthodoxy, church, churches, catholic, eastern, icons, christian, christianity,
# Nearest to dr: director, david, michael, s, by, dean, professor, and,
# Nearest to consists: consisting, consist, divided, each, comprising, branch, are, composed,
# Nearest to resources: resource, natural, arable, land, petroleum, mining, environment, issues,
# Nearest to taking: took, then, another, taken, when, to, after, out,
# Nearest to assembly: legislative, elected, appointed, deputies, council, branch, members, parliament,
# Nearest to numerous: including, many, several, notably, notable, most, especially, various,
# Nearest to construction: constructed, building, built, bridges, build, buildings, opened, completed,
# Epoch 10/10 Iteration: 82100 Avg. Training loss: 4.2650 0.3969 sec/batch
# Epoch 10/10 Iteration: 82200 Avg. Training loss: 4.3380 0.3972 sec/batch
# Epoch 10/10 Iteration: 82300 Avg. Training loss: 4.2708 0.4030 sec/batch
# Epoch 10/10 Iteration: 82400 Avg. Training loss: 4.3670 0.3968 sec/batch
# Epoch 10/10 Iteration: 82500 Avg. Training loss: 4.3301 0.4009 sec/batch
# Epoch 10/10 Iteration: 82600 Avg. Training loss: 4.0870 0.4012 sec/batch
# Epoch 10/10 Iteration: 82700 Avg. Training loss: 4.2741 0.3760 sec/batch
# Epoch 10/10 Iteration: 82800 Avg. Training loss: 4.2416 0.3923 sec/batch
# Epoch 10/10 Iteration: 82900 Avg. Training loss: 4.2154 0.4162 sec/batch
# Epoch 10/10 Iteration: 83000 Avg. Training loss: 4.3002 0.4243 sec/batch
# Nearest to not: that, does, it, so, should, be, but, even,
# Nearest to seven: one, six, eight, four, three, five, nine, zero,
# Nearest to about: from, there, is, have, according, what, how, approximately,
# Nearest to often: sometimes, generally, many, more, as, such, some, different,
# Nearest to it: that, but, not, so, to, be, actually, this,
# Nearest to three: four, five, seven, six, one, two, eight, zero,
# Nearest to to: a, this, the, would, but, in, being, it,
# Nearest to also: of, as, the, is, in, and, a, known,
# Nearest to orthodox: orthodoxy, catholic, churches, icons, christian, jewish, church, oriental,
# Nearest to dr: professor, director, doctor, hopkins, institute, michael, research, dean,
# Nearest to consists: consisting, consist, divided, each, separate, are, composed, called,
# Nearest to resources: resource, arable, land, natural, comprehensive, information, issues, hydropower,
# Nearest to taking: take, given, turns, where, then, find, another, taken,
# Nearest to assembly: legislative, elected, appointed, parliament, elections, deputies, council, branch,
# Nearest to numerous: including, several, notably, many, various, were, most, among,
# Nearest to construction: constructed, built, building, completed, build, bridges, concrete, construct,
# Epoch 10/10 Iteration: 83100 Avg. Training loss: 4.1712 0.3869 sec/batch
# Epoch 10/10 Iteration: 83200 Avg. Training loss: 3.9988 0.3791 sec/batch
# Epoch 10/10 Iteration: 83300 Avg. Training loss: 4.2473 0.3780 sec/batch
# Epoch 10/10 Iteration: 83400 Avg. Training loss: 4.1697 0.3751 sec/batch
# Epoch 10/10 Iteration: 83500 Avg. Training loss: 4.2271 0.3780 sec/batch
# Epoch 10/10 Iteration: 83600 Avg. Training loss: 4.2015 0.3757 sec/batch
# Epoch 10/10 Iteration: 83700 Avg. Training loss: 4.2210 0.3788 sec/batch
# Epoch 10/10 Iteration: 83800 Avg. Training loss: 4.2627 0.3830 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# WARNING:tensorflow:From C:\Users\Dell\anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
